# %% [markdown]
# <a href="https://colab.research.google.com/github/kirath2205/Final-Year-Project/blob/main/Test_bench_cifar_100.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import keras,os
import tensorflow as tf
from keras.models import Sequential,Model
from keras.layers import Input, Add, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv2D, AveragePooling2D, MaxPooling2D , Dropout
import numpy as np
from tensorflow import keras
from keras.initializers import glorot_uniform
from keras import applications
from tensorflow.keras.applications.resnet50 import ResNet50 , preprocess_input
from keras import regularizers

# %%
# !pip install Keras-applications
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: Keras-applications in /usr/local/lib/python3.6/dist-packages (1.0.8)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from Keras-applications) (2.10.0)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.6/dist-packages (from Keras-applications) (1.19.1)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from h5py->Keras-applications) (1.15.0)
# WARNING: You are using pip version 20.2.2; however, version 21.3.1 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
def select_dataset(index):

  if(index==1):
    fashion_mnist = tf.keras.datasets.fashion_mnist.load_data()
    (X_train, y_train), (X_test, y_test) = fashion_mnist

  elif(index==2):
    cifar_10 = tf.keras.datasets.cifar10.load_data()
    (X_train, y_train), (X_test, y_test) = cifar_10
  
  elif(index==3):
    cifar_100 = tf.keras.datasets.cifar100.load_data()
    (X_train, y_train), (X_test, y_test) = cifar_100
    print(len(X_train))

    
  return X_train,y_train,X_test,y_test

# %%
def normalize(X_train,X_test):
    #this function normalize inputs for zero mean and unit variance
    # it is used when training a model.
    # Input: training set and test set
    # Output: normalized training set and test set according to the trianing set statistics.
    mean = np.mean(X_train,axis=(0,1,2,3))
    std = np.std(X_train, axis=(0, 1, 2, 3))
    print(mean)
    print(std)
    X_train = (X_train-mean)/(std+1e-7)
    X_test = (X_test-mean)/(std+1e-7)
    return X_train, X_test

def pre_processing_fashion_mnist(X_train,y_train,X_test,y_test,image_channel):
  img_width = X_train.shape[1]
  img_height = X_train.shape[2]
  input_shape = (img_width, img_height, image_channel)
  
  # normalize data
  X_train, X_test = X_train / 255, X_test / 255

  # reshape input 
  X_train = X_train.reshape(X_train.shape[0], *input_shape)
  X_test = X_test.reshape(X_test.shape[0], *input_shape)

  # one-hot
  y_train = tf.keras.utils.to_categorical(y_train)
  y_test = tf.keras.utils.to_categorical(y_test)

  return X_train,y_train,X_test,y_test,input_shape

def pre_processing_cifar10(X_train,y_train,X_test,y_test,image_channel):
  X_train = X_train.astype('float32')
  X_test = X_test.astype('float32')

  y_train = keras.utils.to_categorical(y_train)
  y_test = keras.utils.to_categorical(y_test)

  X_train = preprocess_input(X_train)
  X_test = preprocess_input(X_test)

  img_width = X_train[0].shape[0]
  img_height = X_train[0].shape[1]
  image_channel = image_channel

  input_shape=(img_width,img_height,image_channel) 
  print(input_shape)
  X_train , X_test = normalize(X_train , X_test)
  return X_train,y_train,X_test,y_test,input_shape
  
def pre_processing_cifar100(X_train,y_train,X_test,y_test,image_channel):
  X_train = X_train.astype('float32')
  X_test = X_test.astype('float32')
  X_train = preprocess_input(X_train)
  X_test = preprocess_input(X_test)

  y_train = keras.utils.to_categorical(y_train)
  y_test = keras.utils.to_categorical(y_test)

  img_width = X_train[0].shape[0]
  img_height = X_train[0].shape[1]
  image_channel = image_channel

  input_shape=(img_width,img_height,image_channel) 
  print(input_shape)
  return X_train,y_train,X_test,y_test,input_shape

# %%
def define_model_vgg16(image_shape,total_classes):
  print(image_shape[2])

  model = Sequential()
  weight_decay = 0.0005
  learning_rate = 0.1
  lr_decay = 1e-6
  lr_drop = 20
  model.add(Conv2D(64, (3, 3), padding='same',
                 input_shape=image_shape,kernel_regularizer=regularizers.l2(weight_decay)))
  model.add(Activation('relu'))
  model.add(BatchNormalization())
  model.add(Dropout(0.3))

  model.add(Conv2D(64, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
  model.add(Activation('relu'))
  model.add(BatchNormalization())
  model.add(MaxPooling2D(pool_size=(2, 2)))

  model.add(Conv2D(128, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
  model.add(Activation('relu'))
  model.add(BatchNormalization())
  model.add(Dropout(0.4))

  model.add(Conv2D(128, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
  model.add(Activation('relu'))
  model.add(BatchNormalization())

  model.add(MaxPooling2D(pool_size=(2, 2)))


  model.add(Conv2D(256, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
  model.add(Activation('relu'))
  model.add(BatchNormalization())
  model.add(Dropout(0.4))

  model.add(Conv2D(256, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
  model.add(Activation('relu'))
  model.add(BatchNormalization())
  model.add(Dropout(0.4))

  model.add(Conv2D(256, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
  model.add(Activation('relu'))
  model.add(BatchNormalization())

  model.add(MaxPooling2D(pool_size=(2, 2)))

  model.add(Conv2D(512, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
  model.add(Activation('relu'))
  model.add(BatchNormalization())
  model.add(Dropout(0.4))

  model.add(Conv2D(512, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
  model.add(Activation('relu'))
  model.add(BatchNormalization())
  model.add(Dropout(0.4))

  model.add(Conv2D(512, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
  model.add(Activation('relu'))
  model.add(BatchNormalization())

  model.add(MaxPooling2D(pool_size=(2, 2)))

  model.add(Conv2D(512, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
  model.add(Activation('relu'))
  model.add(BatchNormalization())
  model.add(Dropout(0.4))

  model.add(Conv2D(512, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
  model.add(Activation('relu'))
  model.add(BatchNormalization())
  model.add(Dropout(0.4))

  model.add(Conv2D(512, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
  model.add(Activation('relu'))
  model.add(BatchNormalization())

  model.add(MaxPooling2D(pool_size=(2, 2)))
  model.add(Dropout(0.5))

  model.add(Flatten())
  model.add(Dense(512,kernel_regularizer=regularizers.l2(weight_decay)))
  model.add(Activation('relu'))
  model.add(BatchNormalization())

  model.add(Dropout(0.5))
  model.add(Dense(total_classes))
  model.add(Activation('softmax'))
  sgd = keras.optimizers.SGD(lr=learning_rate, decay=lr_decay, momentum=0.9, nesterov=True)
  model.compile(optimizer=sgd, loss=keras.losses.categorical_crossentropy, metrics=['accuracy'])
  
  return model

def define_model_standard_cnn(image_shape,total_classes):
  initializer = tf.keras.initializers.he_uniform()
  model = Sequential()
  model.add(Conv2D(32,(3,3), activation = 'relu',  padding = 'same', input_shape = image_shape))
  model.add(Conv2D(32,(3,3), activation = 'relu',  padding = 'same'))
  model.add(MaxPooling2D((2,2)))
  model.add(Dropout(0.2))  
  model.add(Conv2D(64,(3,3), activation = 'relu',  padding = 'same'))
  model.add(Conv2D(64,(3,3), activation = 'relu',  padding = 'same'))
  model.add(MaxPooling2D((2,2)))
  model.add(Dropout(0.2))
  model.add(Conv2D(128,(3,3), activation = 'relu',  padding = 'same'))
  model.add(Conv2D(128,(3,3), activation = 'relu',  padding = 'same'))
  model.add(MaxPooling2D((2,2)))
  model.add(Dropout(0.2))
  model.add(Flatten())
  model.add(Dense(128, activation = 'relu'))
  model.add(Dense(total_classes, activation = 'softmax'))
  opt = keras.optimizers.SGD(learning_rate=0.1 , momentum=0.9)
  model.compile(optimizer=opt,loss=keras.losses.categorical_crossentropy,metrics=['accuracy'])
  return model

def define_model_vgg16_cifar100(image_shape,total_classes):
  print(image_shape[2])

  model = Sequential()
  weight_decay = 0.0005
  learning_rate = 0.001
  lr_decay = 1e-6
  lr_drop = 20
  model.add(Conv2D(64, (3, 3), padding='same',
                 input_shape=image_shape,kernel_regularizer=regularizers.l2(weight_decay)))
  model.add(Activation('relu'))
  model.add(BatchNormalization())
  #model.add(Dropout(0.3))

  model.add(Conv2D(64, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
  model.add(Activation('relu'))
  model.add(BatchNormalization())
  model.add(MaxPooling2D(pool_size=(2, 2)))

  model.add(Conv2D(128, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
  model.add(Activation('relu'))
  model.add(BatchNormalization())
  #model.add(Dropout(0.4))

  model.add(Conv2D(128, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
  model.add(Activation('relu'))
  model.add(BatchNormalization())

  model.add(MaxPooling2D(pool_size=(2, 2)))


  model.add(Conv2D(256, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
  model.add(Activation('relu'))
  model.add(BatchNormalization())
  #model.add(Dropout(0.4))

  model.add(Conv2D(256, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
  model.add(Activation('relu'))
  model.add(BatchNormalization())
  #model.add(Dropout(0.4))

  model.add(Conv2D(256, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
  model.add(Activation('relu'))
  model.add(BatchNormalization())

  model.add(MaxPooling2D(pool_size=(2, 2)))

  model.add(Conv2D(512, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
  model.add(Activation('relu'))
  model.add(BatchNormalization())
  #model.add(Dropout(0.4))

  model.add(Conv2D(512, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
  model.add(Activation('relu'))
  model.add(BatchNormalization())
  #model.add(Dropout(0.4))

  model.add(Conv2D(512, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
  model.add(Activation('relu'))
  model.add(BatchNormalization())

  model.add(MaxPooling2D(pool_size=(2, 2)))

  model.add(Conv2D(512, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
  model.add(Activation('relu'))
  model.add(BatchNormalization())
  #model.add(Dropout(0.25))

  model.add(Conv2D(512, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
  model.add(Activation('relu'))
  model.add(BatchNormalization())
  #model.add(Dropout(0.25))

  model.add(Conv2D(512, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
  model.add(Activation('relu'))
  model.add(BatchNormalization())

  model.add(MaxPooling2D(pool_size=(2, 2)))
  #model.add(Dropout(0.3))
  model.add(Conv2D(1024, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
  model.add(Activation('relu'))
  model.add(BatchNormalization())
  model.add(Conv2D(1024, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
  model.add(Activation('relu'))
  model.add(BatchNormalization())
  model.add(MaxPooling2D(pool_size=(2, 2),padding='same'))

  model.add(Flatten())
  model.add(Dense(1024,kernel_regularizer=regularizers.l2(weight_decay)))
  model.add(Activation('relu'))
  model.add(BatchNormalization())

  #model.add(Dropout(0.25))
  model.add(Dense(total_classes))
  model.add(Activation('softmax'))
  sgd = keras.optimizers.SGD(lr=learning_rate, decay=lr_decay, momentum=0.9, nesterov=True)
  model.compile(optimizer=sgd, loss=keras.losses.categorical_crossentropy, metrics=['accuracy'])
  
  return model

# %%
def identity_block(x, filter):
    # copy tensor to variable called x_skip
    x_skip = x
    # Layer 1
    x = tf.keras.layers.Conv2D(filter, (3,3), padding = 'same')(x)
    x = tf.keras.layers.BatchNormalization(axis=3)(x)
    x = tf.keras.layers.Activation('relu')(x)
    # Layer 2
    x = tf.keras.layers.Conv2D(filter, (3,3), padding = 'same')(x)
    x = tf.keras.layers.BatchNormalization(axis=3)(x)
    # Add Residue
    x = tf.keras.layers.Add()([x, x_skip])     
    x = tf.keras.layers.Activation('relu')(x)
    x = tf.keras.layers.BatchNormalization(axis=3)(x)
    return x

def convolutional_block(x, filter):
    # copy tensor to variable called x_skip
    x_skip = x
    # Layer 1
    x = tf.keras.layers.Conv2D(filter, (3,3), padding = 'same', strides = (2,2))(x)
    x = tf.keras.layers.BatchNormalization(axis=3)(x)
    x = tf.keras.layers.Activation('relu')(x)
    # Layer 2
    x = tf.keras.layers.Conv2D(filter, (3,3), padding = 'same')(x)
    x = tf.keras.layers.BatchNormalization(axis=3)(x)
    # Processing Residue with conv(1,1)
    x_skip = tf.keras.layers.Conv2D(filter, (1,1), strides = (2,2))(x_skip)
    # Add Residue
    x = tf.keras.layers.Add()([x, x_skip])     
    x = tf.keras.layers.Activation('relu')(x)
    #addinf dropout
    x = tf.keras.layers.Dropout(0.25)(x)
    x = tf.keras.layers.BatchNormalization(axis=3)(x)
    return x

def ResNet34(shape, classes):
    learning_rate = 0.001
    lr_decay = 1e-6
    # Step 1 (Setup Input Layer)
    x_input = tf.keras.layers.Input(shape)
    x = tf.keras.layers.ZeroPadding2D((3, 3))(x_input)
    # Step 2 (Initial Conv layer along with maxPool)
    x = tf.keras.layers.Conv2D(64, kernel_size=7, strides=2, padding='same')(x)
    #adding dropout
    x = tf.keras.layers.Dropout(0.25)(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation('relu')(x)
    x = tf.keras.layers.MaxPool2D(pool_size=3, strides=2, padding='same')(x)
    # Define size of sub-blocks and initial filter size
    block_layers = [3, 4, 6, 3]
    filter_size = 64
    # Step 3 Add the Resnet Blocks
    for i in range(4):
        if i == 0:
            # For sub-block 1 Residual/Convolutional block not needed
            for j in range(block_layers[i]):
                x = identity_block(x, filter_size)
        else:
            # One Residual/Convolutional Block followed by Identity blocks
            # The filter size will go on increasing by a factor of 2
            filter_size = filter_size*2
            x = convolutional_block(x, filter_size)
            for j in range(block_layers[i] - 1):
                x = identity_block(x, filter_size)
    # Step 4 End Dense Network
    x = tf.keras.layers.AveragePooling2D((2,2), padding = 'same')(x)
    x = tf.keras.layers.Flatten()(x)
    x = tf.keras.layers.Dense(512, activation = 'relu')(x)
    x = tf.keras.layers.Dense(classes, activation = 'softmax')(x)
    model = tf.keras.models.Model(inputs = x_input, outputs = x, name = "ResNet34")
    sgd = keras.optimizers.SGD(lr=0.001, decay=lr_decay, momentum=0.9, nesterov=True)
    model.compile(optimizer=sgd, loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping
def train_model_vgg16(X_train,y_train,X_test,y_test,epochs=10,batch_size=128):
  
  callbacks = [ 
    tf.keras.callbacks.ModelCheckpoint('best_model_vgg16_cifar_100', monitor='val_accuracy', verbose=1, save_best_only=True),
    tf.keras.callbacks.ReduceLROnPlateau( factor = 0.9, patience = 10, min_lr = 0.0000001, verbose = 1 ),
    tf.keras.callbacks.EarlyStopping(monitor = 'val_loss' , patience = 100)
  ]
  history=model.fit(X_train, y_train, epochs = epochs, batch_size = batch_size,callbacks = callbacks, verbose = 1,validation_data=(X_test,y_test))
  return history

def train_model_standard_cnn(X_train,y_train,X_test,y_test,epochs=10,batch_size=64):
  callbacks = [ 
    tf.keras.callbacks.ModelCheckpoint('best_model_standard_cnn', monitor='val_accuracy', verbose=1, save_best_only=True),
    tf.keras.callbacks.ReduceLROnPlateau( factor = 0.9, patience = 3, min_lr = 0.000001, verbose = 1 ),
    tf.keras.callbacks.EarlyStopping(monitor = 'val_loss' , patience = 15)
  ]
  history=model.fit(X_train , y_train , epochs = epochs , validation_data=(X_test,y_test),batch_size=batch_size , callbacks = callbacks)
  return history


def train_model_resnet34(X_train,y_train,X_test,y_test,epochs=10,batch_size=64):
  callbacks = [ 
    tf.keras.callbacks.ModelCheckpoint('best_model_resnet50_cifar_100', monitor='val_accuracy', verbose=1, save_best_only=True),
    tf.keras.callbacks.ReduceLROnPlateau( factor = 0.9, patience = 10, min_lr = 0.0000001, verbose = 1 ),
    tf.keras.callbacks.EarlyStopping(monitor = 'val_loss' , patience = 50)
  ]
  history=model.fit(X_train , y_train , epochs = epochs , validation_data=(X_test,y_test),batch_size= 64 , callbacks = callbacks)
  return history

# %%
def make_prediction(model,X_test,index):

  return model.predict(X_test(index))

# %%
'''

X_train,y_train,X_test,y_test=select_dataset(2)
X_train,y_train,X_test,y_test,image_shape=pre_processing_cifar10(X_train,y_train,X_test,y_test,3)
model=define_model_standard_cnn(image_shape,10)
history_cnn_model = train_model_standard_cnn(X_train,y_train,X_test,y_test,epochs=100)
model.save('Desktop/cnn_model_cifar10.h5')

X_train,y_train,X_test,y_test=select_dataset(2)
X_train,y_train,X_test,y_test,image_shape=pre_processing_cifar10(X_train,y_train,X_test,y_test,3)
model=ResNet34(image_shape,10)
history_resnet=train_model_resnet34(X_train,y_train,X_test,y_test,epochs=100)
model.save('Desktop/resnet_cifar10.h5') '''

X_train,y_train,X_test,y_test=select_dataset(3)
X_train,y_train,X_test,y_test,image_shape=pre_processing_cifar100(X_train,y_train,X_test,y_test,3)
model=define_model_vgg16_cifar100(image_shape,100)
history_vgg16=train_model_vgg16(X_train,y_train,X_test,y_test,400,32)
model.save('Desktop/vgg16_cifar100.h5')
# Out:
# 50000
# (32, 32, 3)
# 3
# Epoch 1/400
# 1561/1563 [============================>.] - ETA: 0s - loss:
400
# 1561/1563 [============================>.] - ETA: 0s - loss: 3.4676 - accuracy: 0.7523
# Epoch 00012: val_accuracy did not improve from 0.46060
# 1563/1563 [==============================] - 39s 25ms/step - loss: 3.4680 - accuracy: 0.7522 - val_loss: 5.0695 - val_accuracy: 0.4566 - lr: 0.0010
# Epoch 13/400
# 1563/1563 [==============================] - ETA: 0s - loss: 3.3048 - accuracy: 0.7885
# Epoch 00013: val_accuracy did not improve from 0.46060
# 1563/1563 [==============================] - 39s 25ms/step - loss: 3.3048 - accuracy: 0.7885 - val_loss: 5.1324 - val_accuracy: 0.4600 - lr: 0.0010
# Epoch 14/400
# 1561/1563 [============================>.] - ETA: 0s - loss: 3.1515 - accuracy: 0.8226
# Epoch 00014: val_accuracy did not improve from 0.46060
# 1563/1563 [==============================] - 39s 25ms/step - loss: 3.1516 - accuracy: 0.8226 - val_loss: 5.1702 - val_accuracy: 0.4558 - lr: 0.0010
# Epoch 15/400
# 1561/1563 [============================>.] - ETA: 0s - loss: 3.0302 - accuracy: 0.8492
# Epoch 00015: val_accuracy did not improve from 0.46060
# 1563/1563 [==============================] - 39s 25ms/step - loss: 3.0306 - accuracy: 0.8490 - val_loss: 5.2228 - val_accuracy: 0.4573 - lr: 0.0010
# Epoch 16/400
# 1561/1563 [============================>.] - ETA: 0s - loss: 2.9189 - accuracy: 0.8732
# Epoch 00016: val_accuracy improved from 0.46060 to 0.46230, saving model to best_model_vgg16_cifar_100
# INFO:tensorflow:Assets written to: best_model_vgg16_cifar_100/assets
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 0.0009000000427477062.
# 1563/1563 [==============================] - 44s 28ms/step - loss: 2.9189 - accuracy: 0.8732 - val_loss: 5.2435 - val_accuracy: 0.4623 - lr: 0.0010
# Epoch 17/400
# 1561/1563 [============================>.] - ETA: 0s - loss: 2.7406 - accuracy: 0.9158
# Epoch 00017: val_accuracy improved from 0.46230 to 0.47690, saving model to best_model_vgg16_cifar_100
# INFO:tensorflow:Assets written to: best_model_vgg16_cifar_100/assets
# 1563/1563 [==============================] - 44s 28ms/step - loss: 2.7406 - accuracy: 0.9158 - val_loss: 5.2155 - val_accuracy: 0.4769 - lr: 9.0000e-04
# Epoch 18/400
# 1562/1563 [============================>.] - ETA: 0s - loss: 2.6133 - accuracy: 0.9436
# Epoch 00018: val_accuracy improved from 0.47690 to 0.47980, saving model to best_model_vgg16_cifar_100
# INFO:tensorflow:Assets written to: best_model_vgg16_cifar_100/assets
# 1563/1563 [==============================] - 45s 29ms/step - loss: 2.6133 - accuracy: 0.9436 - val_loss: 5.2409 - val_accuracy: 0.4798 - lr: 9.0000e-04
# Epoch 19/400
# 1563/1563 [==============================] - ETA: 0s - loss: 2.5429 - accuracy: 0.9509
# Epoch 00019: val_accuracy improved from 0.47980 to 0.48350, saving model to best_model_vgg16_cifar_100
# INFO:tensorflow:Assets written to: best_model_vgg16_cifar_100/assets
# 1563/1563 [==============================] - 44s 28ms/step - loss: 2.5429 - accuracy: 0.9509 - val_loss: 5.2812 - val_accuracy: 0.4835 - lr: 9.0000e-04
# Epoch 20/400
# 1562/1563 [============================>.] - ETA: 0s - loss: 2.5018 - accuracy: 0.9493
# Epoch 00020: val_accuracy did not improve from 0.48350
# 1563/1563 [==============================] - 39s 25ms/step - loss: 2.5018 - accuracy: 0.9494 - val_loss: 5.3195 - val_accuracy: 0.4744 - lr: 9.0000e-04
# Epoch 21/400
# 1561/1563 [============================>.] - ETA: 0s - loss: 2.4757 - accuracy: 0.9441
# Epoch 00021: val_accuracy did not improve from 0.48350
# 1563/1563 [==============================] - 39s 25ms/step - loss: 2.4757 - accuracy: 0.9441 - val_loss: 5.3080 - val_accuracy: 0.4748 - lr: 9.0000e-04
# Epoch 22/400
# 1561/1563 [============================>.] - ETA: 0s - loss: 2.4518 - accuracy: 0.9392
# Epoch 00022: val_accuracy did not improve from 0.48350
# 1563/1563 [==============================] - 39s 25ms/step - loss: 2.4517 - accuracy: 0.9393 - val_loss: 5.3027 - val_accuracy: 0.4711 - lr: 9.0000e-04
# Epoch 23/400
# 1561/1563 [============================>.] - ETA: 0s - loss: 2.3809 - accuracy: 0.9497
# Epoch 00023: val_accuracy did not improve from 0.48350
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 0.0008100000384729356.
# 1563/1563 [==============================] - 39s 25ms/step - loss: 2.3808 - accuracy: 0.9497 - val_loss: 5.2718 - val_accuracy: 0.4786 - lr: 9.0000e-04
# Epoch 24/400
# 1561/1563 [============================>.] - ETA: 0s - loss: 2.3020 - accuracy: 0.9625
# Epoch 00024: val_accuracy improved from 0.48350 to 0.48860, saving model to best_model_vgg16_cifar_100
# INFO:tensorflow:Assets written to: best_model_vgg16_cifar_100/assets
# 1563/1563 [==============================] - 45s 29ms/step - loss: 2.3022 - accuracy: 0.9625 - val_loss: 5.1154 - val_accuracy: 0.4886 - lr: 8.1000e-04
# Epoch 25/400
# 1561/1563 [============================>.] - ETA: 0s - loss: 2.2225 - accuracy: 0.9759
# Epoch 00025: val_accuracy improved from 0.48860 to 0.49700, saving model to best_model_vgg16_cifar_100
# INFO:tensorflow:Assets written to: best_model_vgg16_cifar_100/assets
# 1563/1563 [==============================] - 44s 28ms/step - loss: 2.2225 - accuracy: 0.9759 - val_loss: 5.1121 - val_accuracy: 0.4970 - lr: 8.1000e-04
# Epoch 26/400
# 1561/1563 [============================>.] - ETA: 0s - loss: 2
saving model to best_model_vgg16_cifar_100
# INFO:tensorflow:Assets written to: best_model_vgg16_cifar_100/assets
# 1563/1563 [==============================] - 44s 28ms/step - loss: 0.7563 - accuracy: 0.9973 - val_loss: 4.2713 - val_accuracy: 0.5145 - lr: 4.7830e-04
# Epoch 107/400
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.7459 - accuracy: 0.9980
# Epoch 00107: val_accuracy did not improve from 0.51450
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.7459 - accuracy: 0.9980 - val_loss: 4.2877 - val_accuracy: 0.5103 - lr: 4.7830e-04
# Epoch 108/400
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.7350 - accuracy: 0.9985
# Epoch 00108: val_accuracy improved from 0.51450 to 0.51870, saving model to best_model_vgg16_cifar_100
# INFO:tensorflow:Assets written to: best_model_vgg16_cifar_100/assets
# 1563/1563 [==============================] - 46s 29ms/step - loss: 0.7350 - accuracy: 0.9985 - val_loss: 4.2545 - val_accuracy: 0.5187 - lr: 4.7830e-04
# Epoch 109/400
# 1563/1563 [==============================] - ETA: 0s - loss: 0.7262 - accuracy: 0.9985
# Epoch 00109: val_accuracy did not improve from 0.51870
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.7262 - accuracy: 0.9985 - val_loss: 4.3130 - val_accuracy: 0.5141 - lr: 4.7830e-04
# Epoch 110/400
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.7167 - accuracy: 0.9986
# Epoch 00110: val_accuracy did not improve from 0.51870
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.7167 - accuracy: 0.9986 - val_loss: 4.3144 - val_accuracy: 0.5151 - lr: 4.7830e-04
# Epoch 111/400
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.7075 - accuracy: 0.9988
# Epoch 00111: val_accuracy improved from 0.51870 to 0.51920, saving model to best_model_vgg16_cifar_100
# INFO:tensorflow:Assets written to: best_model_vgg16_cifar_100/assets
# 1563/1563 [==============================] - 44s 28ms/step - loss: 0.7075 - accuracy: 0.9988 - val_loss: 4.2786 - val_accuracy: 0.5192 - lr: 4.7830e-04
# Epoch 112/400
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.7003 - accuracy: 0.9983
# Epoch 00112: val_accuracy did not improve from 0.51920
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.7003 - accuracy: 0.9983 - val_loss: 4.2801 - val_accuracy: 0.5133 - lr: 4.7830e-04
# Epoch 113/400
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.6916 - accuracy: 0.9984
# Epoch 00113: val_accuracy improved from 0.51920 to 0.51960, saving model to best_model_vgg16_cifar_100
# INFO:tensorflow:Assets written to: best_model_vgg16_cifar_100/assets
# 1563/1563 [==============================] - 46s 29ms/step - loss: 0.6916 - accuracy: 0.9984 - val_loss: 4.2564 - val_accuracy: 0.5196 - lr: 4.7830e-04
# Epoch 114/400
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.6836 - accuracy: 0.9982
# Epoch 00114: val_accuracy did not improve from 0.51960
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.6836 - accuracy: 0.9982 - val_loss: 4.3042 - val_accuracy: 0.5128 - lr: 4.7830e-04
# Epoch 115/400
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.6766 - accuracy: 0.9983
# Epoch 00115: val_accuracy did not improve from 0.51960
#
# Epoch 00115: ReduceLROnPlateau reducing learning rate to 0.0004304672533180565.
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.6766 - accuracy: 0.9983 - val_loss: 4.2811 - val_accuracy: 0.5162 - lr: 4.7830e-04
# Epoch 116/400
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.6680 - accuracy: 0.9986
# Epoch 00116: val_accuracy improved from 0.51960 to 0.52050, saving model to best_model_vgg16_cifar_100
# INFO:tensorflow:Assets written to: best_model_vgg16_cifar_100/assets
# 1563/1563 [==============================] - 44s 28ms/step - loss: 0.6680 - accuracy: 0.9986 - val_loss: 4.2400 - val_accuracy: 0.5205 - lr: 4.3047e-04
# Epoch 117/400
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.6606 - accuracy: 0.9986
# Epoch 00117: val_accuracy improved from 0.52050 to 0.52150, saving model to best_model_vgg16_cifar_100
# INFO:tensorflow:Assets written to: best_model_vgg16_cifar_100/assets
# 1563/1563 [==============================] - 44s 28ms/step - loss: 0.6606 - accuracy: 0.9986 - val_loss: 4.2633 - val_accuracy: 0.5215 - lr: 4.3047e-04
# Epoch 118/400
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.6534 - accuracy: 0.9985
# Epoch 00118: val_accuracy did not improve from 0.52150
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.6534 - accuracy: 0.9985 - val_loss: 4.2414 - val_accuracy: 0.5170 - lr: 4.3047e-04
# Epoch 119/400
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.6453 - accuracy: 0.9989
# Epoch 00119: val_accuracy did not improve from 0.52150
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.6453 - accuracy: 0.9989 - val_loss: 4.2522 - val_accuracy: 0.5195 - lr: 4.3047e-04
# Epoch 120/400
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.6386 - accuracy: 0.9988
# Epoch 00120: val_accuracy did not improve from 0.52150
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.6386 - accuracy: 0.9988 - val_loss: 4.2554 - val_accuracy: 0.5148 - lr: 4.3047e-04
# Epoch 121/400
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.
#
# Epoch 00137: ReduceLROnPlateau reducing learning rate to 0.0003486784757114947.
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.5466 - accuracy: 0.9969 - val_loss: 4.3506 - val_accuracy: 0.5072 - lr: 3.8742e-04
# Epoch 138/400
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.5434 - accuracy: 0.9968
# Epoch 00138: val_accuracy did not improve from 0.52300
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.5433 - accuracy: 0.9968 - val_loss: 4.3196 - val_accuracy: 0.5062 - lr: 3.4868e-04
# Epoch 139/400
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.5350 - accuracy: 0.9982
# Epoch 00139: val_accuracy did not improve from 0.52300
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.5350 - accuracy: 0.9982 - val_loss: 4.3168 - val_accuracy: 0.5116 - lr: 3.4868e-04
# Epoch 140/400
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.5327 - accuracy: 0.9976
# Epoch 00140: val_accuracy did not improve from 0.52300
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.5327 - accuracy: 0.9976 - val_loss: 4.3535 - val_accuracy: 0.5054 - lr: 3.4868e-04
# Epoch 141/400
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.5290 - accuracy: 0.9974
# Epoch 00141: val_accuracy did not improve from 0.52300
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.5290 - accuracy: 0.9974 - val_loss: 4.2926 - val_accuracy: 0.5064 - lr: 3.4868e-04
# Epoch 142/400
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.5237 - accuracy: 0.9978
# Epoch 00142: val_accuracy did not improve from 0.52300
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.5238 - accuracy: 0.9978 - val_loss: 4.2687 - val_accuracy: 0.5113 - lr: 3.4868e-04
# Epoch 143/400
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.5223 - accuracy: 0.9973
# Epoch 00143: val_accuracy did not improve from 0.52300
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.5223 - accuracy: 0.9973 - val_loss: 4.2988 - val_accuracy: 0.5107 - lr: 3.4868e-04
# Epoch 144/400
# ...
# Epoch 00351: val_accuracy did not improve from 0.53350
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.2130 - accuracy: 0.9997 - val_loss: 4.0159 - val_accuracy: 0.5334 - lr: 5.2335e-05
# Epoch 352/400
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.2128 - accuracy: 0.9998
# Epoch 00352: val_accuracy did not improve from 0.53350
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.2128 - accuracy: 0.9998 - val_loss: 4.0181 - val_accuracy: 0.5335 - lr: 5.2335e-05
# Epoch 353/400
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.2126 - accuracy: 0.9998
# Epoch 00353: val_accuracy did not improve from 0.53350
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.2126 - accuracy: 0.9998 - val_loss: 4.0165 - val_accuracy: 0.5328 - lr: 5.2335e-05
# Epoch 354/400
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.2123 - accuracy: 0.9998
# Epoch 00354: val_accuracy did not improve from 0.53350
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.2123 - accuracy: 0.9998 - val_loss: 4.0170 - val_accuracy: 0.5331 - lr: 5.2335e-05
# Epoch 355/400
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.2121 - accuracy: 0.9998
# Epoch 00355: val_accuracy did not improve from 0.53350
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.2121 - accuracy: 0.9998 - val_loss: 4.0116 - val_accuracy: 0.5330 - lr: 5.2335e-05
# Epoch 356/400
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.2119 - accuracy: 0.9998
# Epoch 00356: val_accuracy improved from 0.53350 to 0.53420, saving model to best_model_vgg16_cifar_100
# INFO:tensorflow:Assets written to: best_model_vgg16_cifar_100/assets
# 1563/1563 [==============================] - 45s 29ms/step - loss: 0.2119 - accuracy: 0.9998 - val_loss: 4.0171 - val_accuracy: 0.5342 - lr: 5.2335e-05
# Epoch 357/400
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.2117 - accuracy: 0.9997
# Epoch 00357: val_accuracy did not improve from 0.53420
#
# Epoch 00357: ReduceLROnPlateau reducing learning rate to 4.7101289601414466e-05.
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.2117 - accuracy: 0.9997 - val_loss: 4.0101 - val_accuracy: 0.5340 - lr: 5.2335e-05
# Epoch 358/400
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.2114 - accuracy: 0.9998
# Epoch 00358: val_accuracy did not improve from 0.53420
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.2114 - accuracy: 0.9998 - val_loss: 4.0121 - val_accuracy: 0.5331 - lr: 4.7101e-05
# Epoch 359/400
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.2113 - accuracy: 0.9997
# Epoch 00359: val_accuracy did not improve from 0.53420
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.2113 - accuracy: 0.9997 - val_loss: 4.0175 - val_accuracy: 0.5324 - lr: 4.7101e-05
# Epoch 360/400
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.2111 - accuracy: 0.9998
# Epoch 00360: val_accuracy did not improve from 0.53420
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.2111 - accuracy: 0.9998 - val_loss: 4.0101 - val_accuracy: 0.5321 - lr: 4.7101e-05
# Epoch 361/400
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.2109 - accuracy: 0.9997
# Epoch 00361: val_accuracy did not improve from 0.53420
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.2109 - accuracy: 0.9997 - val_loss: 4.0145 - val_accuracy: 0.5324 - lr: 4.7101e-05
# Epoch 362/400
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.2106 - accuracy: 0.9999
# Epoch 00362: val_accuracy did not improve from 0.53420
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.2106 - accuracy: 0.9999 - val_loss: 4.0153 - val_accuracy: 0.5325 - lr: 4.7101e-05
# Epoch 363/400
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.2104 - accuracy: 0.9999
# Epoch 00363: val_accuracy did not improve from 0.53420
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.2104 - accuracy: 0.9999 - val_loss: 4.0126 - val_accuracy: 0.5332 - lr: 4.7101e-05
# Epoch 364/400
# 1563/1563 [==============================] - ETA: 0s - loss: 0.2102 - accuracy: 0.9998
# Epoch 00364: val_accuracy did not improve from 0.53420
#
# Epoch 00364: ReduceLROnPlateau reducing learning rate to 4.239116096869111e-05.
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.2102 - accuracy: 0.9998 - val_loss: 4.0119 - val_accuracy: 0.5328 - lr: 4.7101e-05
# Epoch 365/400
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.2101 - accuracy: 0.9998
# Epoch 00365: val_accuracy did not improve from 0.53420
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.2101 - accuracy: 0.9998 - val_loss: 4.0073 - val_accuracy: 0.5339 - lr: 4.2391e-05
# Epoch 366/400
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.2099 - accuracy: 0.9997
# Epoch 00366: val_accuracy did not improve from 0.53420
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.2099 - accuracy: 0.9997 - val_loss: 4.0156 - val_accuracy: 0.5338 - lr: 4.2391e-05
# Epoch 367/400
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.2097 - accuracy: 0.9998
# Epoch 00367: val_accuracy did not improve from 0.53420
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.2097 - accuracy: 0.9998 - val_loss: 4.0120 - val_accuracy: 0.5323 - lr: 4.2391e-05
# Epoch 368/400
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.2095 - accuracy: 0.9998
# Epoch 00368: val_accuracy did not improve from 0.53420
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.2095 - accuracy: 0.9998 - val_loss: 4.0068 - val_accuracy: 0.5331 - lr: 4.2391e-05
# Epoch 369/400
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.2094 - accuracy: 0.9998
# Epoch 00369: val_accuracy did not improve from 0.53420
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.2094 - accuracy: 0.9998 - val_loss: 4.0159 - val_accuracy: 0.5336 - lr: 4.2391e-05
# Epoch 370/400
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.2092 - accuracy: 0.9998
# Epoch 00370: val_accuracy did not improve from 0.53420
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.2092 - accuracy: 0.9998 - val_loss: 4.0061 - val_accuracy: 0.5331 - lr: 4.2391e-05
# Epoch 371/400
# 1563/1563 [==============================] - ETA: 0s - loss: 0.2090 - accuracy: 0.9998
# Epoch 00371: val_accuracy improved from 0.53420 to 0.53440, saving model to best_model_vgg16_cifar_100
# INFO:tensorflow:Assets written to: best_model_vgg16_cifar_100/assets
# 1563/1563 [==============================] - 44s 28ms/step - loss: 0.2090 - accuracy: 0.9998 - val_loss: 4.0117 - val_accuracy: 0.5344 - lr: 4.2391e-05
# Epoch 372/400
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.2088 - accuracy: 0.9998
# Epoch 00372: val_accuracy did not improve from 0.53440
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.2088 - accuracy: 0.9998 - val_loss: 4.0113 - val_accuracy: 0.5326 - lr: 4.2391e-05
# Epoch 373/400
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.2086 - accuracy: 0.9998
# Epoch 00373: val_accuracy did not improve from 0.53440
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.2086 - accuracy: 0.9998 - val_loss: 4.0084 - val_accuracy: 0.5329 - lr: 4.2391e-05
# Epoch 374/400
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.2085 - accuracy: 0.9998
# Epoch 00374: val_accuracy did not improve from 0.53440
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.2085 - accuracy: 0.9998 - val_loss: 4.0146 - val_accuracy: 0.5329 - lr: 4.2391e-05
# Epoch 375/400
# 1563/1563 [==============================] - ETA: 0s - loss: 0.2083 - accuracy: 0.9999
# Epoch 00375: val_accuracy did not improve from 0.53440
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.2083 - accuracy: 0.9999 - val_loss: 4.0138 - val_accuracy: 0.5329 - lr: 4.2391e-05
# Epoch 376/400
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.2081 - accuracy: 0.9998
# Epoch 00376: val_accuracy did not improve from 0.53440
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.2081 - accuracy: 0.9998 - val_loss: 4.0131 - val_accuracy: 0.5331 - lr: 4.2391e-05
# Epoch 377/400
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.2079 - accuracy: 0.9999
# Epoch 00377: val_accuracy did not improve from 0.53440
#
# Epoch 00377: ReduceLROnPlateau reducing learning rate to 3.815204618149437e-05.
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.2079 - accuracy: 0.9999 - val_loss: 4.0098 - val_accuracy: 0.5336 - lr: 4.2391e-05
# Epoch 378/400
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.2078 - accuracy: 0.9999
# Epoch 00378: val_accuracy did not improve from 0.53440
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.2078 - accuracy: 0.9999 - val_loss: 4.0052 - val_accuracy: 0.5318 - lr: 3.8152e-05
# Epoch 379/400
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.2076 - accuracy: 0.9998
# Epoch 00379: val_accuracy did not improve from 0.53440
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.2076 - accuracy: 0.9998 - val_loss: 4.0116 - val_accuracy: 0.5324 - lr: 3.8152e-05
# Epoch 380/400
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.2075 - accuracy: 0.9998
# Epoch 00380: val_accuracy did not improve from 0.53440
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.2075 - accuracy: 0.9998 - val_loss: 4.0060 - val_accuracy: 0.5328 - lr: 3.8152e-05
# Epoch 381/400
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.2073 - accuracy: 0.9999
# Epoch 00381: val_accuracy did not improve from 0.53440
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.2073 - accuracy: 0.9999 - val_loss: 4.0021 - val_accuracy: 0.5333 - lr: 3.8152e-05
# Epoch 382/400
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.2072 - accuracy: 0.9998
# Epoch 00382: val_accuracy did not improve from 0.53440
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.2072 - accuracy: 0.9998 - val_loss: 4.0120 - val_accuracy: 0.5331 - lr: 3.8152e-05
# Epoch 383/400
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.2070 - accuracy: 0.9998
# Epoch 00383: val_accuracy did not improve from 0.53440
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.2070 - accuracy: 0.9998 - val_loss: 4.0083 - val_accuracy: 0.5338 - lr: 3.8152e-05
# Epoch 384/400
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.2069 - accuracy: 0.9998
# Epoch 00384: val_accuracy did not improve from 0.53440
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.2069 - accuracy: 0.9998 - val_loss: 4.0085 - val_accuracy: 0.5322 - lr: 3.8152e-05
# Epoch 385/400
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.2067 - accuracy: 0.9998
# Epoch 00385: val_accuracy did not improve from 0.53440
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.2067 - accuracy: 0.9998 - val_loss: 4.0124 - val_accuracy: 0.5322 - lr: 3.8152e-05
# Epoch 386/400
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.2065 - accuracy: 0.9998
# Epoch 00386: val_accuracy did not improve from 0.53440
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.2065 - accuracy: 0.9998 - val_loss: 4.0050 - val_accuracy: 0.5329 - lr: 3.8152e-05
# Epoch 387/400
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.2064 - accuracy: 0.9998
# Epoch 00387: val_accuracy did not improve from 0.53440
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.2064 - accuracy: 0.9998 - val_loss: 4.0084 - val_accuracy: 0.5338 - lr: 3.8152e-05
# Epoch 388/400
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.2063 - accuracy: 0.9998
# Epoch 00388: val_accuracy did not improve from 0.53440
#
# Epoch 00388: ReduceLROnPlateau reducing learning rate to 3.4336842873017304e-05.
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.2063 - accuracy: 0.9998 - val_loss: 4.0099 - val_accuracy: 0.5332 - lr: 3.8152e-05
# Epoch 389/400
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.2061 - accuracy: 0.9997
# Epoch 00389: val_accuracy did not improve from 0.53440
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.2061 - accuracy: 0.9997 - val_loss: 4.0093 - val_accuracy: 0.5326 - lr: 3.4337e-05
# Epoch 390/400
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.2060 - accuracy: 0.9997
# Epoch 00390: val_accuracy did not improve from 0.53440
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.2060 - accuracy: 0.9997 - val_loss: 4.0053 - val_accuracy: 0.5332 - lr: 3.4337e-05
# Epoch 391/400
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.2058 - accuracy: 0.9999
# Epoch 00391: val_accuracy did not improve from 0.53440
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.2058 - accuracy: 0.9999 - val_loss: 4.0107 - val_accuracy: 0.5326 - lr: 3.4337e-05
# Epoch 392/400
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.2057 - accuracy: 0.9997
# Epoch 00392: val_accuracy did not improve from 0.53440
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.2057 - accuracy: 0.9997 - val_loss: 4.0000 - val_accuracy: 0.5330 - lr: 3.4337e-05
# Epoch 393/400
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.2056 - accuracy: 0.9998
# Epoch 00393: val_accuracy did not improve from 0.53440
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.2056 - accuracy: 0.9998 - val_loss: 4.0043 - val_accuracy: 0.5329 - lr: 3.4337e-05
# Epoch 394/400
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.2054 - accuracy: 0.9998
# Epoch 00394: val_accuracy did not improve from 0.53440
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.2054 - accuracy: 0.9998 - val_loss: 4.0115 - val_accuracy: 0.5339 - lr: 3.4337e-05
# Epoch 395/400
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.2053 - accuracy: 0.9999
# Epoch 00395: val_accuracy did not improve from 0.53440
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.2053 - accuracy: 0.9999 - val_loss: 4.0086 - val_accuracy: 0.5335 - lr: 3.4337e-05
# Epoch 396/400
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.2051 - accuracy: 0.9999
# Epoch 00396: val_accuracy did not improve from 0.53440
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.2051 - accuracy: 0.9999 - val_loss: 4.0011 - val_accuracy: 0.5337 - lr: 3.4337e-05
# Epoch 397/400
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.2050 - accuracy: 0.9998
# Epoch 00397: val_accuracy did not improve from 0.53440
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.2050 - accuracy: 0.9998 - val_loss: 4.0072 - val_accuracy: 0.5329 - lr: 3.4337e-05
# Epoch 398/400
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.2049 - accuracy: 0.9998
# Epoch 00398: val_accuracy did not improve from 0.53440
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.2049 - accuracy: 0.9998 - val_loss: 4.0057 - val_accuracy: 0.5331 - lr: 3.4337e-05
# Epoch 399/400
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.2048 - accuracy: 0.9998
# Epoch 00399: val_accuracy did not improve from 0.53440
#
# Epoch 00399: ReduceLROnPlateau reducing learning rate to 3.0903160222806036e-05.
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.2048 - accuracy: 0.9998 - val_loss: 4.0032 - val_accuracy: 0.5331 - lr: 3.4337e-05
# Epoch 400/400
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.2046 - accuracy: 0.9998
# Epoch 00400: val_accuracy did not improve from 0.53440
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.2046 - accuracy: 0.9998 - val_loss: 3.9964 - val_accuracy: 0.5335 - lr: 3.0903e-05

# %%
X_train,y_train,X_test,y_test=select_dataset(3)
X_train,y_train,X_test,y_test,image_shape=pre_processing_cifar100(X_train,y_train,X_test,y_test,3)
model=ResNet34(image_shape,100)
history_resnet=train_model_resnet34(X_train,y_train,X_test,y_test,epochs=400)
model.save('Desktop/resnet_cifar100.h5')
# Out:
# 50000
# (32, 32, 3)
# Epoch 1/400
# 781/782 [============================>.] - ETA: 0s - loss: 4.4569 - accuracy: 0.0312
# Epoch 00001: val_accuracy improved from -inf to 0.02520, saving model to best_model_resnet50_cifar_100
# INFO:tensorflow:Assets written to: best_model_resnet50_cifar_100/assets
# 782/782 [==============================] - 30s 38ms/step - loss: 4.4567 - accuracy: 0.0313 - val_loss: 4.4440 - val_accuracy: 0.0252 - lr: 0.0010
# Epoch 2/400
# 781/782 [============================>.] - ETA: 0s - loss: 4.0742 - accuracy: 0.0688
# Epoch 00002: val_accuracy improved from 0.02520 to 0.06090, saving model to best_model_resnet50_cifar_100
# INFO:tensorflow:Assets written to: best_model_resnet50_cifar_100/assets
# 782/782 [==============================] - 31s 40ms/step - loss: 4.0742 - accuracy: 0.0688 - val_loss: 4.1273 - val_accuracy: 0.0609 - lr: 0.0010
# Epoch 3/400
# 782/782 [==============================] - ETA: 0s - loss: 3.7924 - accuracy: 0.1138
# Epoch 00003: val_accuracy improved from 0.06090 to 0.09960, saving model to best_model_resnet50_cifar_100
# INFO:tensorflow:Assets written to: best_model_resnet50_cifar_100/assets
# 782/782 [==============================] - 29s 37ms/step - loss: 3.7924 - accuracy: 0.1138 - val_loss: 3.8809 - val_accuracy: 0.0996 - lr: 0.0010
# Epoch 4/400
# 781/782 [============================>.] - ETA: 0s - loss: 3.5760 - accuracy: 0.1494
# Epoch 00004: val_accuracy improved from 0.09960 to 0.13370, saving model to best_model_resnet50_cifar_100
# INFO:tensorflow:Assets written to: best_model_resnet50_cifar_100/assets
# 782/782 [==============================] - 31s 40ms/step - loss: 3.5759 - accuracy: 0.1494 - val_loss: 3.7046 - val_accuracy: 0.1337 - lr: 0.0010
# Epoch 5/400
# 774/782 [============================>.] - ETA: 0s - loss: 3.4171 - accuracy: 0.1765

# %%
import matplotlib.pyplot as plt

''' 

# Visualize history
# Plot history: Loss
plt.figure(figsize = (10,8))
plt.plot(history_cnn_model.history['val_loss'])
plt.title('Validation loss history cnn_model')
plt.ylabel('Loss value')
plt.xlabel('No. epoch')
plt.show()

# Plot history: Accuracy
plt.figure(figsize = (10,8))
plt.plot(history_cnn_model.history['val_accuracy'])
plt.title('Validation accuracy history cnn_model')
plt.ylabel('Accuracy value (%)')
plt.xlabel('No. epoch')
plt.show()
'''
'''
print()
# Visualize history
# Plot history: Loss
plt.figure(figsize = (10,8))
plt.plot(history_resnet.history['val_loss'])
plt.title('Validation loss history resnet')
plt.ylabel('Loss value')
plt.xlabel('No. epoch')
plt.show()

# Plot history: Accuracy
plt.figure(figsize = (10,8))
plt.plot(history_resnet.history['val_accuracy'])
plt.title('Validation accuracy history resnet')
plt.ylabel('Accuracy value (%)')
plt.xlabel('No. epoch')
plt.show()
'''
# Visualize history
# Plot history: Loss
plt.figure(figsize = (10,8))
plt.plot(history_vgg16.history['val_loss'])
plt.title('Validation loss history vgg16')
plt.ylabel('Loss value')
plt.xlabel('No. epoch')
plt.show()
print()
# Plot history: Accuracy
plt.figure(figsize = (10,8))
plt.plot(history_vgg16.history['val_accuracy'])
plt.title('Validation accuracy history vgg16')
plt.ylabel('Accuracy value (%)')
plt.xlabel('No. epoch')
plt.show()

# %%
# Visualize history
# Plot history: Loss
plt.figure(figsize = (10,8))
plt.plot(history_resnet.history['val_loss'])
plt.title('Validation loss history vgg16')
plt.ylabel('Loss value')
plt.xlabel('No. epoch')
plt.show()
print()
# Plot history: Accuracy
plt.figure(figsize = (10,8))
plt.plot(history_resnet.history['val_accuracy'])
plt.title('Validation accuracy history vgg16')
plt.ylabel('Accuracy value (%)')
plt.xlabel('No. epoch')
plt.show()

# %%
# !pip freeze > requirements.txt

# %%
'''X_train,y_train,X_test,y_test=select_dataset(1)
X_train,y_train,X_test,y_test,image_shape=pre_processing_fashion_mnist(X_train,y_train,X_test,y_test,1)
model=define_model_standard_cnn(image_shape,10)
history_cnn_model_mnist = train_model_standard_cnn(X_train,y_train,X_test,y_test,epochs=100)
model.save('Desktop/cnn_model_mnist.h5')'''
'''
X_train,y_train,X_test,y_test=select_dataset(1)
X_train,y_train,X_test,y_test,image_shape=pre_processing_fashion_mnist(X_train,y_train,X_test,y_test,1)
model=ResNet34(image_shape,10)
history_resnet_mnist =train_model_resnet34(X_train,y_train,X_test,y_test,epochs=100)
model.save('Desktop/resnet_mnist.h5')'''
'''
X_train,y_train,X_test,y_test=select_dataset(1)
X_train,y_train,X_test,y_test,image_shape=pre_processing_fashion_mnist(X_train,y_train,X_test,y_test,1)
model=define_model_vgg16(image_shape,10)
history_vgg16_mnist=train_model_vgg16(X_train,y_train,X_test,y_test,epochs=100)
model.save('Desktop/vgg16_mnist.h5')'''

# %%
import matplotlib.pyplot as plt



# Visualize history
# Plot history: Loss
plt.figure(figsize = (10,8))
plt.plot(history_cnn_model_mnist.history['val_loss'])
plt.title('Validation loss history cnn_model')
plt.ylabel('Loss value')
plt.xlabel('No. epoch')
plt.show()

# Plot history: Accuracy
plt.figure(figsize = (10,8))
plt.plot(history_cnn_model_mnist.history['val_accuracy'])
plt.title('Validation accuracy history cnn_model')
plt.ylabel('Accuracy value (%)')
plt.xlabel('No. epoch')
plt.show()

print()
# Visualize history
# Plot history: Loss
plt.figure(figsize = (10,8))
plt.plot(history_resnet_mnist.history['val_loss'])
plt.title('Validation loss history resnet')
plt.ylabel('Loss value')
plt.xlabel('No. epoch')
plt.show()

# Plot history: Accuracy
plt.figure(figsize = (10,8))
plt.plot(history_resnet_mnist.history['val_accuracy'])
plt.title('Validation accuracy history resnet')
plt.ylabel('Accuracy value (%)')
plt.xlabel('No. epoch')
plt.show()

# Visualize history
# Plot history: Loss
plt.figure(figsize = (10,8))
plt.plot(history_vgg16_mnist.history['val_loss'])
plt.title('Validation loss history vgg16')
plt.ylabel('Loss value')
plt.xlabel('No. epoch')
plt.show()
print()
# Plot history: Accuracy
plt.figure(figsize = (10,8))
plt.plot(history_vgg16_mnist.history['val_accuracy'])
plt.title('Validation accuracy history vgg16')
plt.ylabel('Accuracy value (%)')
plt.xlabel('No. epoch')
plt.show()
